# %%
from mymodule import divide

division = divide(3,5)

print(division)
# Out:
# 0.6

# %%
import sys

print(sys.path)
# Out:
# ['c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\Advanced', 'c:\\Users\\Altieres\\.vscode\\extensions\\ms-toolsai.jupyter-2021.3.684299474\\pythonFiles\\.does-not-exist', 'c:\\Users\\Altieres\\.vscode\\extensions\\ms-toolsai.jupyter-2021.3.684299474\\pythonFiles', 'c:\\Users\\Altieres\\.vscode\\extensions\\ms-toolsai.jupyter-2021.3.684299474\\pythonFiles\\lib\\python', 'c:\\users\\altieres\\appdata\\local\\programs\\python\\python39\\python39.zip', 'c:\\users\\altieres\\appdata\\local\\programs\\python\\python39\\DLLs', 'c:\\users\\altieres\\appdata\\local\\programs\\python\\python39\\lib', 'c:\\users\\altieres\\appdata\\local\\programs\\python\\python39', 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env', '', 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages', 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\win32', 'c:\\Users\\Altieres\\Documents\\Pyt
# ...

# %%
import libs.mylib

print (libs.mylib)
# Out:
# mylib.py libs.mylib
# <module 'libs.mylib' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\Advanced\\libs\\mylib.py'>

# %%
import mymodule
import sys

print(sys.modules)
# Out:
# ar\\socket.py'>, 'zmq.sugar.context': <module 'zmq.sugar.context' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\zmq\\sugar\\context.py'>, 'zmq.sugar.frame': <module 'zmq.sugar.frame' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\zmq\\sugar\\frame.py'>, 'zmq.sugar.tracker': <module 'zmq.sugar.tracker' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\zmq\\sugar\\tracker.py'>, 'zmq.sugar.version': <module 'zmq.sugar.version' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\zmq\\sugar\\version.py'>, 'zmq.sugar.stopwatch': <module 'zmq.sugar.stopwatch' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\\lib\\site-packages\\zmq\\sugar\\stopwatch.py'>, 'zmq.sugar': <module 'zmq.sugar' from 'c:\\Users\\Altieres\\Documents\\Python\\curso-testes-automatizados\\env\
# ...
